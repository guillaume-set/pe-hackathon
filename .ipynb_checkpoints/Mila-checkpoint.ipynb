# %%
import pandas as pd
import matplotlib.pyplot as plt


lien_apple_un_an = "1y apple.csv"

df = pd.read_csv(lien_apple_un_an)
pd.to_datetime(df['Date'])
df.head()
# Out:
#          Date Close/Last    Volume     Open       High      Low
# 0  10/30/2023    $170.29  51130960  $169.02    $171.17  $168.87
# 1  10/27/2023    $168.22  58499130  $166.91    $168.96  $166.83
# 2  10/26/2023    $166.89  70625260  $170.37  $171.3775  $165.67
# 3  10/25/2023    $171.10  57156960  $171.88    $173.06  $170.65
# 4  10/24/2023    $173.44  43816640  $173.05    $173.67  $171.45

# %%
temps=df['Date']
high_auctions=df['High']
low_auctions=df['Low']

# %%
df.dtypes

#problème sur les types des données de chaque colonne : il y a un signe $ devant chaque donnée numérique
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
df['high new']=df['High'].str.replace('$','').astype(float)
df
# Out:
#             Date Close/Last     Volume      Open       High       Low  \
# 0     10/30/2023    $170.29   51130960   $169.02    $171.17   $168.87
# 1     10/27/2023    $168.22   58499130   $166.91    $168.96   $166.83
# 2     10/26/2023    $166.89   70625260   $170.37  $171.3775   $165.67
# 3     10/25/2023    $171.10   57156960   $171.88    $173.06   $170.65
# 4     10/24/2023    $173.44   43816640   $173.05    $173.67   $171.45
# ...          ...        ...        ...       ...        ...       ...
# 1252  11/06/2018   $50.9425  127098880    $50.48     $51.18  $50.4225
# 1253  11/05/2018   $50.3975  264288680   $51.075   $51.0975  $49.5425
# 1254  11/02/2018     $51.87  364186240  $52.3875   $53.4125  $51.3575
# 1255  11/01/2018    $55.555  211816280  $54.7625     $55.59  $54.2025
# 1256  10/31/2018    $54.715  152067240    $54.22   $55.1125   $54.155
#
#       high new
# 0     171.1700
# 1     168.9600
# 2     171.3775
# 3     173.0600
# 4     173.6700
# ...        ...
# 1252   51.1800
# 1253   51.0975
# 1254   53.4125
# 1255   55.5900
# 1256   55.1125
#
# [1257 rows x 7 columns]

# %%
df['Low new']=df['Low'].str.replace('$','').astype(float)
df
# Out:
#             Date Close/Last     Volume      Open       High       Low  \
# 0     10/30/2023    $170.29   51130960   $169.02    $171.17   $168.87
# 1     10/27/2023    $168.22   58499130   $166.91    $168.96   $166.83
# 2     10/26/2023    $166.89   70625260   $170.37  $171.3775   $165.67
# 3     10/25/2023    $171.10   57156960   $171.88    $173.06   $170.65
# 4     10/24/2023    $173.44   43816640   $173.05    $173.67   $171.45
# ...          ...        ...        ...       ...        ...       ...
# 1252  11/06/2018   $50.9425  127098880    $50.48     $51.18  $50.4225
# 1253  11/05/2018   $50.3975  264288680   $51.075   $51.0975  $49.5425
# 1254  11/02/2018     $51.87  364186240  $52.3875   $53.4125  $51.3575
# 1255  11/01/2018    $55.555  211816280  $54.7625     $55.59  $54.2025
# 1256  10/31/2018    $54.715  152067240    $54.22   $55.1125   $54.155
#
#       high new   Low new
# 0     171.1700  168.8700
# 1     168.9600  166.8300
# 2     171.3775  165.6700
# 3     173.0600  170.6500
# 4     173.6700  171.4500
# ...        ...       ...
# 1252   51.1800   50.4225
# 1253   51.0975   49.5425
# 1254   53.4125   51.3575
# 1255   55.5900   54.2025
# 1256   55.1125   54.1550
#
# [1257 rows x 8 columns]

# %%
df.dtypes
# Out:
# Date           object
# Close/Last     object
# Volume          int64
# Open           object
# High           object
# Low            object
# high new      float64
# Low new       float64
# dtype: object

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.plot(df['Date'], df['high new'],df['Low new'])
# Out:
# [<matplotlib.lines.Line2D at 0x11ea21550>,
#  <matplotlib.lines.Line2D at 0x11bd8b8d0>]

# %%
difference = df['high new']-df['Low new']
#colonne qui regarde l'écart entre le max et le min#

# %%
difference
# Out:
# 0       2.3000
# 1       2.1300
# 2       5.7075
# 3       2.4100
# 4       2.2200
#          ...
# 1252    0.7575
# 1253    1.5550
# 1254    2.0550
# 1255    1.3875
# 1256    0.9575
# Length: 1257, dtype: float64

# %%
plt.plot(df['Date'], difference)

# %%
df.boxplot
# Out:
# <bound method boxplot_frame of             Date Close/Last     Volume      Open       High       Low  \
# 0     10/30/2023    $170.29   51130960   $169.02    $171.17   $168.87
# 1     10/27/2023    $168.22   58499130   $166.91    $168.96   $166.83
# 2     10/26/2023    $166.89   70625260   $170.37  $171.3775   $165.67
# 3     10/25/2023    $171.10   57156960   $171.88    $173.06   $170.65
# 4     10/24/2023    $173.44   43816640   $173.05    $173.67   $171.45
# ...          ...        ...        ...       ...        ...       ...
# 1252  11/06/2018   $50.9425  127098880    $50.48     $51.18  $50.4225
# 1253  11/05/2018   $50.3975  264288680   $51.075   $51.0975  $49.5425
# 1254  11/02/2018     $51.87  364186240  $52.3875   $53.4125  $51.3575
# 1255  11/01/2018    $55.555  211816280  $54.7625     $55.59  $54.2025
# 1256  10/31/2018    $54.715  152067240    $54.22   $55.1125   $54.155
#
#       high new   Low new
# 0     171.1700  168.8700
# 1     168.9600  166.8300
# 2     171.3775  165.6700
# 3     173.0600  170.6500
# 4     173.6700  171.4500
# ...        ...       ...
# 1252   51.1800   50.4225
# 1253   51.0975   49.5425
# 1254   53.4125   51.3575
# 1255   55.5900   54.2025
# 1256   55.1125   54.1550
#
# [1257 rows x 8 columns]>
